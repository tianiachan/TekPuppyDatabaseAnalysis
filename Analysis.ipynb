# %%
#dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import Column, Integer, String
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from config import username, password

# %%
#set up sqlalchemy to connect to database and grab session
engine = create_engine(f"mysql+pymysql://{username}:{password}@localhost/puppydb")
# Base = automap_base()
# Base.prepare(engine, reflect=True)
conn = engine.connect()
# session = Session(engine)

# %%
# pip install pymysql

# %%
# #table names
# Base.classes.keys()
# #set each table reference to a variable
# owners = Base.classes.owners
# puppies = Base.classes.puppies

# %%
puppydf = pd.read_sql("SELECT * FROM puppies",conn)
ownerdf = pd.read_sql("SELECT * FROM owners",conn)
#set index of both dataframes
ownerdf = ownerdf.set_index('id')
puppydf = puppydf.set_index('id')
# ownerdf = ownerdf.reset_index()
# ownerdf
puppydf
# Out:
#            name    size  age             breed activity_mode
# id
# 1          Flix   large    6   German Shepherd         hyper
# 2           Bid   small    3           Basenji         hyper
# 3         Blade  medium    7          Pit Bull  couch potato
# 4      Callahan   large    5  Alaskan Malamute       regular
# 5        Hammer   large    8             Akita       regular
# 6          Huck  medium    4         Shiba Inu         hyper
# 7       Pancake  medium    7           Samoyed  couch potato
# 8         Poach   small    6      Bichon Frise  couch potato
# 9        Savage   small    2        Pomeranian         hyper
# 10      Scoober  medium    6         Dalmatian         hyper
# 11  Sea Biscuit   large   10       St. Bernard  couch potato

# %%
# puppylarge = session.query(puppies).filter(puppies.size == "large").count()
# puppymedium = session.query(puppies).filter(puppies.size == "medium").count()
# puppysmall = session.query(puppies).filter(puppies.size == "small").count()
# print(f'There are {puppylarge} large puppies in our adoption database.')
# print(f'There are {puppymedium} large puppies in our adoption database.')
# print(f'There are {puppysmall} small puppies in our adoption database.')

# %%
#average age of puppies put up for adoption  in our database
# avgpuppyage = puppydf['age'].mean()
# print(int(avgage))
# Out:
# 5

# %%
#get counts from each table
print(ownerdf.count())
# Out:
# name        11
# email       11
# puppy_id    11
# dtype: int64

# %%
print(puppydf.count())
# Out:
# name             11
# size             11
# age              11
# breed            11
# activity_mode    11
# dtype: int64

# %%
#number of columns per table
puppydf_shape = puppydf.shape
num_puppy_columns = puppydf_shape[1]
print(f'The number of columns in our puppy table is {num_puppy_columns} and they are {puppydf.columns.tolist()}')
ownerdf_shape = ownerdf.shape
num_owner_columns = ownerdf_shape[1]
print(f'The number of columns in our foster pawrent table is {num_owner_columns} and they are {ownerdf.columns.tolist()}.')
# Out:
# The number of columns in our puppy table is 5 and they are ['name', 'size', 'age', 'breed', 'activity_mode']
# The number of columns in our foster pawrent table is 3.

# %%
#group puppies by activity level and show the count of dogs of a certain activity level
puppy_activity_count = puppydf.groupby(['activity_mode','size']).count()
puppy_activity_count
# Out:
#                       name  age  breed
# activity_mode size
# couch potato  large      1    1      1
#               medium     2    2      2
#               small      1    1      1
# hyper         large      1    1      1
#               medium     2    2      2
#               small      2    2      2
# regular       large      2    2      2

# %%
#this shows the age and number of dogs 
puppy_age_count = puppydf.groupby(puppydf['age']).count()
puppy_age_count
#can do further correlation by finding relationship between ex: size and breed or size and age to see if there are similiarities there
#no group by analysis needed for owner since is only a one to one relationship and did not ask for more inforation from owner to do analysis
# Out:
#      name  size  breed  activity_mode
# age
# 2       1     1      1              1
# 3       1     1      1              1
# 4       1     1      1              1
# 5       1     1      1              1
# 6       3     3      3              3
# 7       2     2      2              2
# 8       1     1      1              1
# 10      1     1      1              1

# %%
#section for batch load
# puppydf = pd.read_sql("SELECT * FROM puppies",conn)
# ownerdf = pd.read_sql("SELECT * FROM owners",conn)

#read in csv
puppycsv_df = pd.read_csv('exampledatapuppies.csv')
ownercsv_df = pd.read_csv('exampledataowners.csv')

ownercsv_df
# Out:
#     id     name               email  puppy_id
# 0    1    Thang     thang@gmail.com        11
# 1    2   Kimmie    kimmie@gmail.com         1
# 2    3     Alex      alex@gmail.com         2
# 3    4     Drum    drum@outlook.com         3
# 4    5    Emily     emily@gmail.com         4
# 5    6    Blake   blake@outlook.com         5
# 6    7  Anthony   anthony@gmail.com         6
# 7    8   Kelsey  kelsey@hotmail.com         7
# 8    9   Curtis  curtis@outlook.com         8
# 9   10      Ian         ian@aol.com         9
# 10  11    Steve     steve@gmail.com        10
